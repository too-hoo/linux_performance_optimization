# %% [markdown]
# # Linux 性能优化

# %% [markdown]
# 资            Applications   自上向下是：应用负载视角（吞吐，时延...）
#
# 源            Libraries
#
# 视            System Call
#
# (CPU,         Linux Kernel
#
# 内存           Device
#
# ...)
#
# 自底向上

# %% [markdown]
# 性能优化思维导图
#
# Linux性能优化：
# - 1、文件系统
#
#     (1)文件系统原理
#         虚拟文件系统
#         文件系统I/O栈
#         文件系统缓存
#         文件系统种类
#     (2)性能指标
#         容量
#         IOPS
#         缓存命中率
#     (3)性能剖析
#         df
#         strace
#         vmstat
#         sar
#         perf
#         proc文件系统
#
#     (4)调优方法
#         文件系统类型
#         利用文件系统缓存
#         I/O隔离
# - 2、Linux内核
#     (1) 内核原理
#         内核态
#     (2) 性能剖析
#         BPF
#         perf
#         proc文件系统
#     (3) 内核调优
#         内核选项
#
# - 3、应用程序
#     (1)性能指标
#         吞吐量
#         响应时间
#         资源使用率
#     (2)性能剖析
#         USE方法
#             使用率
#             饱和度
#             错误
#         进程剖析
#             进程状态
#             资源使用率
#             I/O剖析
#             系统调用
#             热点函数
#             动态追踪
#         APM
#     (3)调优方法
#         逻辑简化
#         编程语言
#         算法调优
#         非阻塞I/O
#         利用缓存与缓冲区
#         异步处理与并发
#         垃圾回收
#
# - 4、架构设计
#     (1)空间换时间
#         缓存
#         缓冲区
#         冗余数据
#     (2)时间换空间
#         压缩编码
#         页面交换
#     (3)并行处理
#         多线程
#         多进程
#         分布式
#     (4)异步处理
#         异步I/O
#         消息队列
#         事件通知
# - 5、性能监控
#     (1) 时间序列分析
#         历史趋势分析
#         性能模型构建
#         未来趋势预测
#     (2) 服务调用追踪
#         服务调用流程跟踪
#         服务调用性能分析
#         服务调用链拓扑展示
#     (3) 数据可视化
#         趋势图
#         散点图
#         热力图
#         饼图
#     (4) 告警通知
#         阈值选择
#         报警策略
#         通知渠道
# - 6、性能测试
#     (1) 明确需求
#         系统资源需求
#         应用程序需求
#     (2) 环境假设
#         合理的假设
#         生产环境模拟
#         生产负载模拟
#     (3) 性能测试
#         基准测试
#         负载测试
#         压力测试
#     (4) 结果分析
#         应用程序瓶颈
#         数据库瓶颈
#         系统资源瓶颈
# - 7、磁盘IO
#     (1) 磁盘原理
#         磁盘管理
#         磁盘类型
#         磁盘接口
#         磁盘I/O栈
#     (2) 性能指标
#         使用率
#         IOPS
#         吞吐量
#         IOWAIT
#     (3) 性能剖析
#         dstat
#         sar
#         iostat
#         pidstat
#         iotop
#         iolatency
#         blktrace
#         fio
#         perf
#     (4) 调优方法
#         系统调用
#         I/O资源控制
#         充分利用缓存
#         RAID
#         I/O隔离
# - 8、网络
#     (1) 网络原理
#         网络配置
#         TCP/IP协议
#         网络收发流程
#         高级路由
#         网络QoS
#         网络防火墙
#         C10K与C100K
#     (2) 性能指标
#         吞吐量
#             BPS
#             QPS
#             PPS
#         延迟
#         丢包
#         TCP 重传
#     (3) 性能剖析
#         ethtool
#         sar
#         ping
#         netstat/ss
#         ifstat
#         ifconfig
#         tcpdump
#         wireshark
#         iptables
#         traceroute
#         ipcontrack
#         perf
#     (4) 调优方法
#         网卡调优
#             MTU
#             队列长度
#             链路聚合
#         协议调优
#             HTTP
#             TCP
#             Overlay
#         资源控制
#             QoS
#         内核调优
#             NAT调优
#             功能卸载
#             负载均衡
#             DPDK
# - 9、内存
#     (1) 内存原理
#         地址空间
#         虚拟内存
#         内存分配与回收
#         缓存与缓冲区
#         SWAP
#     (2) 性能指标
#         系统内存的使用量
#         进程内存使用量
#         缓存与缓冲区命中率
#         SWAP使用量
#     (3) 性能剖析
#         free
#         top
#         sar
#         vmstat
#         cachstat
#         cachetop
#         memleak
#         proc文件系统
#     (4) 调优方法
#         利用缓存与缓冲区
#         减少SWAP使用
#         减少动态内存分配
#         优化NUMA
#         限制进程内存资源
#         使用HugePage
# - 10、CPU
#     (1) 进程和CPU原理
#         进程与线程
#         CPU调度
#         中断系统
#         CPU缓存
#         NUMA
#     (2) 性能指标
#         平均负载
#         CPU使用率
#             用户CPU
#             系统CPU
#             IOWAIT
#             软中端
#             硬中断
#             窃取CPU
#             客户CPU
#         上下文切换
#             自愿上下文切换
#             非自愿上下文切换
#         CPU缓存命中率
#     (3) 性能剖析
#         top/ps
#         vmstat
#         mpstat
#         sar
#         pidstat
#         strace
#         perf
#         execsnoop
#         proc文件系统
#     (4) 调优方法
#         CPU绑定
#         进程CPU资源限制
#         进程优先级调整
#         中断负载均衡
#         CPU缓存
#         NUMA优化

# %% [markdown]
# ![Linux 性能优化图标](./linux_perf_tools_full.png)
